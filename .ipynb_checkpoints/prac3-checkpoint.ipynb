# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
colors = pd.Series(['green', 'blue', 'yellow'])
colors
# Out:
# 0     green
# 1      blue
# 2    yellow
# dtype: object

# %%
cars = pd.Series(['ford', 'chevy', 'dodge'])
cars
# Out:
# 0     ford
# 1    chevy
# 2    dodge
# dtype: object

# %%
new_cars = pd.DataFrame({'Car Make': cars, 'color': colors})
new_cars
# Out:
#   Car Make   color
# 0     ford   green
# 1    chevy    blue
# 2    dodge  yellow

# %%
car_sales = pd.read_csv('car_sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv('cs_exp3', index=False)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
nums = pd.Series([7,21,777])
nums.mean()
# Out:
# 268.3333333333333

# %%
nums.sum()
# Out:
# 805

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
car_sales['Price'].plot()

# %%
car_sales['Make'] = car_sales['Make'].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
missing_cars = pd.read_csv('missing_car_data.csv')
missing_cars
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_cars['Odometer'].fillna(car_sales['Odometer (KM)'].mean(), inplace=True)
missing_cars
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500
# 6   Honda    NaN   78601.4    4.0   $7,500
# 7   Honda   Blue   78601.4    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
remove_cars = missing_cars.dropna()

# %%
remove_cars
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   78601.4    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   78601.4    4.0   $4,500

# %%
remove_cars['Seats'] = 5
remove_cars
# Out:
# <ipython-input-43-e4c5a5dc3dc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_cars['Seats'] = 5
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000      5
# 1   Honda    Red   87899.0    4.0   $5,000      5
# 2  Toyota   Blue   78601.4    3.0   $7,000      5
# 3     BMW  Black   11179.0    5.0  $22,000      5
# 4  Nissan  White  213095.0    4.0   $3,500      5
# 5  Toyota  Green   78601.4    4.0   $4,500      5

# %%
remove_cars['Engine Size'] = [1.6, 3.7, 3.3, 4.2, 3.7, 2.7]
remove_cars
# Out:
# <ipython-input-44-5f7e79ac0a2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remove_cars['Engine Size'] = [1.6, 3.7, 3.3, 4.2, 3.7, 2.7]
#      Make Colour  Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.0    4.0   $4,000      5          1.6
# 1   Honda    Red   87899.0    4.0   $5,000      5          3.7
# 2  Toyota   Blue   78601.4    3.0   $7,000      5          3.3
# 3     BMW  Black   11179.0    5.0  $22,000      5          4.2
# 4  Nissan  White  213095.0    4.0   $3,500      5          3.7
# 5  Toyota  Green   78601.4    4.0   $4,500      5          2.7

# %%
car_sales['PvK'] = car_sales['Odometer (KM)'] / car_sales['Price']
# Out:
#      Make Colour  Odometer (KM)  Doors  Price        PvK
# 0  toyota  White         150043      4   4000  37.510750
# 1   honda    Red          87899      4   5000  17.579800
# 2  toyota   Blue          32549      3   7000   4.649857
# 3     bmw  Black          11179      5  22000   0.508136
# 4  nissan  White         213095      4   3500  60.884286
# 5  toyota  Green          99213      4   4500  22.047333
# 6   honda   Blue          45698      4   7500   6.093067
# 7   honda   Blue          54738      4   7000   7.819714
# 8  toyota  White          60000      4   6250   9.600000
# 9  nissan  White          31600      4   9700   3.257732

# %%
car_sales.drop('PvK', axis=1, inplace=True)
car_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-08ef2acfdd36> in <module>
# ----> 1 car_sales.drop('PvK', axis=1, inplace=True)
#       2 car_sales
#
# ~/Desktop/Machine_Learning/Base_project/env/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/Desktop/Machine_Learning/Base_project/env/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
shuf_cars = car_sales.sample(frac=1)
shuf_cars
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 5  toyota  Green          99213      4   4500
# 8  toyota  White          60000      4   6250
# 0  toyota  White         150043      4   4000
# 4  nissan  White         213095      4   3500
# 3     bmw  Black          11179      5  22000
# 9  nissan  White          31600      4   9700

# %%
shuf_cars.loc[3]
# Out:
# Make               bmw
# Colour           Black
# Odometer (KM)    11179
# Doors                5
# Price            22000
# Name: 3, dtype: object

# %%
shuf_cars.iloc[3]
# Out:
# Make             toyota
# Colour             Blue
# Odometer (KM)     32549
# Doors                 3
# Price              7000
# Name: 2, dtype: object

# %%
shuf_cars = shuf_cars.reset_index(drop=True)
shuf_cars
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   honda   Blue          45698      4   7500
# 1   honda   Blue          54738      4   7000
# 2   honda    Red          87899      4   5000
# 3  toyota   Blue          32549      3   7000
# 4  toyota  Green          99213      4   4500
# 5  toyota  White          60000      4   6250
# 6  toyota  White         150043      4   4000
# 7  nissan  White         213095      4   3500
# 8     bmw  Black          11179      5  22000
# 9  nissan  White          31600      4   9700

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White      93776.875      4   4000
# 1   honda    Red      54936.875      4   5000
# 2  toyota   Blue      20343.125      3   7000
# 3     bmw  Black       6986.875      5  22000
# 4  nissan  White     133184.375      4   3500
# 5  toyota  Green      62008.125      4   4500
# 6   honda   Blue      28561.250      4   7500
# 7   honda   Blue      34211.250      4   7000
# 8  toyota  White      37500.000      4   6250
# 9  nissan  White      19750.000      4   9700

# %%
car_sales = car_sales.rename(columns={'Odometer (KM)': 'Odometer (Miles)'})
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price
# 0  toyota  White         93776.875      4   4000
# 1   honda    Red         54936.875      4   5000
# 2  toyota   Blue         20343.125      3   7000
# 3     bmw  Black          6986.875      5  22000
# 4  nissan  White        133184.375      4   3500
# 5  toyota  Green         62008.125      4   4500
# 6   honda   Blue         28561.250      4   7500
# 7   honda   Blue         34211.250      4   7000
# 8  toyota  White         37500.000      4   6250
# 9  nissan  White         19750.000      4   9700
